# %%
dev = "ADD YOUTUBE API KEY HERE"

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="-FMGGp_Wa18",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="-GJgqIJsTME", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      69 non-null     object
#  1   updated_at  69 non-null     object
#  2   like_count  69 non-null     int64
#  3   text        69 non-null     object
#  4   public      69 non-null     bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 2.4+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'LTlTC7z_FR-rQ6HyUPb0lOu1SeQ',
#  'id': 'UgxKrHGhE2WJTxNZgid4AaABAg',
#  'snippet': {'channelId': 'UCl8zB2LZOiLLV0jYUMpTEgA',
#   'videoId': '-FMGGp_Wa18',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'PaqNAr3pRj9qLZXVJXi4kOY-W44',
#    'id': 'UgxKrHGhE2WJTxNZgid4AaABAg',
#    'snippet': {'channelId': 'UCl8zB2LZOiLLV0jYUMpTEgA',
#     'videoId': '-FMGGp_Wa18',
#     'textDisplay': 'These english speaking people will teach us what democracy is... Us aid is stopped now... Very sorry',
#     'textOriginal': 'These english speaking people will teach us what democracy is... Us aid is stopped now... Very sorry',
#     'authorDisplayName': '@sanjeevpingle846',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/T64O9skWKWvOS-YkKSwIfTEaMXIYoCT_UKQPJF4572AvWBXDmp9-XwkoLbJ58iMWyJ_tFi-urow=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@sanjeevpingle846',
#     'authorChannelId': {'value': 'UCThaFwP8KkiB872HG9TBuKg'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2025-02-18T13:33:17Z',
#     'updatedAt': '2025-02-18T13:34:28Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.head(10)
# Out:
#                             author            updated_at  like_count  \
# 0                @sanjeevpingle846  2025-02-18T13:33:17Z           0
# 1                          @Kali97  2024-12-22T17:23:35Z           0
# 2                       @GuruShiju  2024-12-17T03:52:48Z           0
# 3                       @GuruShiju  2024-12-17T03:51:52Z           0
# 4  @gopaakrishnanmvenkataraman9129  2024-11-08T10:38:13Z           1
# 5                     @IndicWing88  2024-09-28T13:07:19Z           0
# 6              @mariafernandes6486  2024-09-07T07:32:23Z           0
# 7              @venkataramanan-n9j  2024-09-06T05:15:18Z           0
# 8           @arjunsinghrathore9252  2024-09-05T20:46:03Z           2
# 9             @yogeshgogawekar5284  2024-09-04T17:18:54Z           0
#
#                                                 text  public
# 0  These english speaking people will teach us wh...    True
# 1                         Why is the audio so off...    True
# 2                             Indincinwonindinpurlot    True
# 3                              Tvsisersindinmanelose    True
# 4  Left liberal will keep on defining democracy o...    True
# 5  The discussion is a way to divert attention so...    True
# 6  A discussion way above the usual, I must say i...    True
# 7  All these democratic talkers will do only talk...    True
# 8  Shame on you all puppets of breaking India for...    True
# 9  Thanks to have such wonderful conversation. En...    True

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                 author            updated_at  like_count  \
# 51             @rc2k22  2024-09-01T01:39:44Z          29
# 68        @rakeshp4215  2024-08-31T14:15:57Z          22
# 33  @vedanshmishra8803  2024-09-01T20:25:26Z          11
# 48        @sunilnm1680  2024-09-01T04:40:34Z          11
# 12    @ankushpatel8455  2024-09-03T23:16:21Z          10
# 62  @madanhawaldar9950  2024-08-31T18:39:56Z           8
# 60  @sanjayghevade1830  2024-08-31T18:56:13Z           8
# 39  @anandkulkarni8313  2024-09-01T13:34:15Z           7
# 52             @nv9991  2024-09-01T00:32:29Z           7
# 45         @Tsechen287  2024-09-01T07:17:06Z           6
#
#                                                  text  public
# 51  These are thr people who focus on Hindutva in ...    True
# 68  The future of democracy is bleak till this dic...    True
# 33  Openly saying that caste should be used to dis...    True
# 48  Thankful to have a discussion in English.\nI t...    True
# 12                        Arm chair philosophers 😂😂😂😂    True
# 62                             He is a congress spoon    True
# 60  Bunch of usless minds her teaching us on democ...    True
# 39  It would help to have this discussion in the U...    True
# 52  I am not only a supporter of Partition (of Ind...    True
# 45  I understand India is slightly leaning towards...    True

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=100
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=100, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','video_id','public'])
  return df2


df = getcomments('qmn9bHEgqqY')
df
# Out:
#                   author            updated_at  like_count  \
# 0               @hadappa  2025-02-17T17:59:47Z           0
# 1       @saisrinivas4099  2025-02-16T17:07:59Z           1
# 2       @yujirohanma2885  2025-02-16T16:54:23Z           0
# 3             @Max-sp4kt  2025-02-16T15:45:01Z           1
# 4           @LamiNalchor  2025-02-16T15:27:06Z           2
# ..                   ...                   ...         ...
# 68     @thereisnogod6240  2025-02-15T05:35:58Z           0
# 69    @tejashbharucha831  2025-02-15T05:34:39Z           5
# 70  @SubramanianRaju-r1t  2025-02-15T05:31:16Z          32
# 71           @ramadasan7  2025-02-15T05:23:16Z          32
# 72     @SouvikPaul-bz5sl  2025-02-15T05:06:36Z          28
#
#                                                  text     video_id  public
# 0   My notion changed for this man respect for him...  qmn9bHEgqqY    True
# 1   This is “New India”🔥 Now we have all Ties Acro...  qmn9bHEgqqY    True
# 2   Next time we should do our voted mark on middl...  qmn9bHEgqqY    True
# 3   Indians have so much power that they can turn ...  qmn9bHEgqqY    True
# 4   well, they don't value it at home too much. so...  qmn9bHEgqqY    True
# ..                                                ...          ...     ...
# 68  india is not a democracy, india is an aparthei...  qmn9bHEgqqY    True
# 69      Bravo, what a great reply by  Jaishankar !❤❤❤  qmn9bHEgqqY    True
# 70                As always, Well said Mr. Jaishankar  qmn9bHEgqqY    True
# 71  👏👏👏👏👏 to Mr. S. Jaishankar  the External Affar...  qmn9bHEgqqY    True
# 72                                  S Jaishankar ❤️🇮🇳  qmn9bHEgqqY    True
#
# [73 rows x 6 columns]

# %%
df = pd.DataFrame()
for i in ['dZJSYY9KYYo','EMUxukvWmIg','0FGBtyTdYHk','Tl0jKo4oE98']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])

# %%
df
# Out:
#                      author            updated_at  like_count  \
# 0           @clemalford9768  2025-02-19T09:10:29Z           0
# 1      @Dackdonaldchyne6459  2025-02-19T09:10:14Z           0
# 2           @razakkalik9072  2025-02-19T08:52:35Z           0
# 3           @razakkalik9072  2025-02-19T08:48:27Z           0
# 4             @Rachid-cg2qy  2025-02-19T08:46:39Z           0
# ..                      ...                   ...         ...
# 136              @bvrao6085  2025-02-15T13:07:27Z          44
# 137  @robloxarsenalnoob6836  2025-02-15T13:07:01Z           0
# 138          @somureddy7227  2025-02-15T13:05:17Z           0
# 139        @jameschacko1296  2025-02-15T13:02:21Z           1
# 140       @prasadkilaru9447  2025-02-15T12:53:27Z           5
#
#                                                   text     video_id  public
# 0                           He tells it like it is!!😮😅  dZJSYY9KYYo    True
# 1                                 This person is lying  dZJSYY9KYYo    True
# 2    India rank 105 out of 127 on the global hunger...  dZJSYY9KYYo    True
# 3              There's a lot of hungry people in India  dZJSYY9KYYo    True
# 4    India the biggest racist system with the caste...  dZJSYY9KYYo    True
# ..                                                 ...          ...     ...
# 136                                   Tharoor is right  Tl0jKo4oE98    True
# 137                            Too smart ! But no use.  Tl0jKo4oE98    True
# 138                    You will be shown door by sonia  Tl0jKo4oE98    True
# 139                                                 ❤👍  Tl0jKo4oE98    True
# 140  Don’t be too honest in your opinions. Unless y...  Tl0jKo4oE98    True
#
# [4626 rows x 6 columns]

# %%
df['video_id'].value_counts()
# Out:
# video_id
# dZJSYY9KYYo    2693
# i-ioasRPc-M     594
# Tl0jKo4oE98     141
# uy7gqT_1BWE     113
# Name: count, dtype: int64

# %%
csv_filename = "youtube_comments.csv"
df.to_csv(csv_filename, index=False, encoding="utf-8")

# Download the file in Google Colab
from google.colab import files
files.download(csv_filename)

print(f"CSV file '{csv_filename}' saved and ready for download.")
# Out:
# CSV file 'youtube_comments.csv' saved and ready for download.
